# %% [markdown]
# # NLP Basics Assignment
# ## Section B – Practical Questions (P1–P20)

# %% [markdown]
# ## P1

# %%
# Store a sentence in a variable
sentence = "I love Artificial Intelligence"

# Print the data type
print(type(sentence))

# %% [markdown]
# ## P2

# %%
# Store the sentence
sentence = "I love NLP"

# Count total characters
print(len(sentence))

# %% [markdown]
# ## P3

# %%
# Store the sentence
sentence = "I love Natural Language Processing"

# Split into words
words = sentence.split()

# Print words
print(words)

# Print total words
print(len(words))

# %% [markdown]
# ## P4

# %%
# Store the message
message = "You have won a free prize"

# Check if 'free' exists
print("free" in message)

# %% [markdown]
# ## P5

# %%
# Store the message
message = "Congratulations! You won a lottery."

# Check for spam keyword
if "Congratulations" in message:
    print("Possible Spam")
else:
    print("Not Spam")

# %% [markdown]
# ## P6

# %%
import pandas as pd

# Create sample dataset
data = {
    "Review": ["Amazing phone", "Bad battery", "Excellent camera", "Poor service"],
    "Sentiment": ["Positive", "Negative", "Positive", "Negative"]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
df

# %% [markdown]
# ## P7

# %%
import pandas as pd

# Create sample dataset
data = {
    "Review": ["Amazing phone", "Bad battery", "Excellent camera", "Poor service"],
    "Sentiment": ["Positive", "Negative", "Positive", "Negative"]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
df

# Display shape
print(df.shape)

# Display summary
df.info()

# %% [markdown]
# ## P8

# %%
import pandas as pd

# Create sample dataset
data = {
    "Review": ["Amazing phone", "Bad battery", "Excellent camera", "Poor service"],
    "Sentiment": ["Positive", "Negative", "Positive", "Negative"]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
df

# First five rows
print(df.head())

# Last five rows
print(df.tail())

# %% [markdown]
# ## P9

# %%
import pandas as pd

# Create sample dataset
data = {
    "Review": ["Amazing phone", "Bad battery", "Excellent camera", "Poor service"],
    "Sentiment": ["Positive", "Negative", "Positive", "Negative"]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
df

# Count sentiment values
print(df["Sentiment"].value_counts())

# %% [markdown]
# ## P10

# %%
import pandas as pd

# Create sample dataset
data = {
    "Review": ["Amazing phone", "Bad battery", "Excellent camera", "Poor service"],
    "Sentiment": ["Positive", "Negative", "Positive", "Negative"]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
df

# Convert reviews to lowercase
df["Review"]=df["Review"].str.lower()
print(df)

# %% [markdown]
# ## P11

# %%
import pandas as pd

# Create sample dataset
data = {
    "Review": ["Amazing phone", "Bad battery", "Excellent camera", "Poor service"],
    "Sentiment": ["Positive", "Negative", "Positive", "Negative"]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
df

# Add Length column using apply(len)
df["Length"]=df["Review"].apply(len)
print(df)

# %% [markdown]
# ## P12

# %%
import pandas as pd

# Create sample dataset
data = {
    "Review": ["Amazing phone", "Bad battery", "Excellent camera", "Poor service"],
    "Sentiment": ["Positive", "Negative", "Positive", "Negative"]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
df

# Print each review one by one
for review in df["Review"]:
    print(review)

# %% [markdown]
# ## P13

# %%
import pandas as pd

# Create sample dataset
data = {
    "Review": ["Amazing phone", "Bad battery", "Excellent camera", "Poor service"],
    "Sentiment": ["Positive", "Negative", "Positive", "Negative"]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
df

# Check if each review contains 'phone'
print(df["Review"].str.contains("phone"))

# %% [markdown]
# ## P14

# %%
import pandas as pd

# Create sample dataset
data = {
    "Review": ["Amazing phone", "Bad battery", "Excellent camera", "Poor service"],
    "Sentiment": ["Positive", "Negative", "Positive", "Negative"]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
df

# Display only positive reviews
print(df[df["Sentiment"]=="Positive"])

# %% [markdown]
# ## P15

# %%
import pandas as pd

# Create sample dataset
data = {
    "Review": ["Amazing phone", "Bad battery", "Excellent camera", "Poor service"],
    "Sentiment": ["Positive", "Negative", "Positive", "Negative"]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
df

# Add character count column
df["Characters"]=df["Review"].str.len()
print(df)

# %% [markdown]
# ## P16

# %%
import pandas as pd

# Create sample dataset
data = {
    "Review": ["Amazing phone", "Bad battery", "Excellent camera", "Poor service"],
    "Sentiment": ["Positive", "Negative", "Positive", "Negative"]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
df

# Add word count column
df["Words"]=df["Review"].apply(lambda x: len(x.split()))
print(df)

# %% [markdown]
# ## P17

# %%
import pandas as pd

movies = pd.DataFrame({
    "Review":["Great movie","Worst acting","Loved the story","Too boring","Fantastic visuals","Waste of time"],
    "Sentiment":["Positive","Negative","Positive","Negative","Positive","Negative"]
})

movies

# Display only negative reviews
print(movies[movies["Sentiment"]=="Negative"])

# %% [markdown]
# ## P18

# %%
import pandas as pd

movies = pd.DataFrame({
    "Review":["Great movie","Worst acting","Loved the story","Too boring","Fantastic visuals","Waste of time"],
    "Sentiment":["Positive","Negative","Positive","Negative","Positive","Negative"]
})

movies

# Add character length
movies["Length"]=movies["Review"].str.len()

# Display longest review
print(movies.loc[movies["Length"].idxmax()])

# %% [markdown]
# ## P19

# %%
import pandas as pd

movies = pd.DataFrame({
    "Review":["Great movie","Worst acting","Loved the story","Too boring","Fantastic visuals","Waste of time"],
    "Sentiment":["Positive","Negative","Positive","Negative","Positive","Negative"]
})

movies

# Count sentiments
print(movies["Sentiment"].value_counts())

# %% [markdown]
# ## P20

# %%
import pandas as pd

feedback = pd.DataFrame({
"Comment":[
"Excellent teacher","Very helpful","Good explanation","Loved the class","Nice examples",
"Too fast","Needs improvement","Confusing lecture","Poor notes","Not satisfied"],
"Sentiment":[
"Positive","Positive","Positive","Positive","Positive",
"Negative","Negative","Negative","Negative","Negative"]
})

# Display first five records
print(feedback.head())

# Display last five records
print(feedback.tail())
